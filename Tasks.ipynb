# %% [markdown]
# <a href="https://colab.research.google.com/github/pavelmaks/testcolabnote/blob/main2/Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Целочисленное деление и остаток
# Достаточно важный модуль для дальнейшего изучения программирования. Разбираем деление нацело и взятия остатка. Пытаемся разобраться с самыми сложными вопросами, связанными с этими задачами

# %% [markdown]
# ## Задача 5/16. Пирожки
#
# Кролик Клевер пошел в пекарню за пирожками. Один пирожок стоит a рублей и b копеек. Определите, сколько рублей и копеек нужно заплатить за n пирожков.
#
#
# ### Входные данные
# Программа получает на вход три целых числа: a, b, n.
#
# ### Выходные данные
# Программа должна вывести два числа: стоимость покупки в рублях и копейках (формат вывода смотри в примерах).

# %%
a, b, n = map(int, input().split())
s = (a*100+b)*n
sk = s % 100
sr = s // 100
sr, "rub. ", sk,djxnvksdjnvkds "kop."
# Out:
# 10 2 4
# (40, 'rub. ', 8, 'kop.')

# %%
print(42/(4+2*(-3)))
# Out:
# -21.0

# %%
2014**14
# Out:
# 18064773765607550801425251468864907833685590016

# %%
2014.0**14
# Out:
# 1.806477376560755e+46

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

# %%
print(a)
# Out:
# 5
